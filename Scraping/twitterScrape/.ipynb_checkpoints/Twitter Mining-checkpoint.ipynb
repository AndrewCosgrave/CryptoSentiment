# %%
# Import packages
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

import time
import json

# %%
# Connection Variables
ckey = 'ggPeuyOVpihbEyzU5VuOLf1X6'
csecret = '4az3kAfUlHp2igVYzEDEtTMWn0ulVmgWqA7svC6GvyFkBws3R3'
atoken = '949197744333295616-PZYls8QOHxHbxmRlS39A3zeeKRipzL2'
asecret = 'PRbWSpcmsn3pQHd1wUI1CQHLwZj1g1Q03upx8OtxDI1zf'

# %%
class listener(StreamListener):
    def on_data(self,data):
        try:
            all_data = json.loads(data)
            
            # Just extract out the tweet from rich featureset
            tweet = all_data["text"]
            print(tweet)
            
            saveFile = open('bitcoin.csv','a')
            saveFile.write(tweet)
            saveFile.write('\n')
            saveFile.close()
            return True
        except BaseException as e:
            print(e)
            time.sleep(5)
    
    def on_error(self,status):
        print (status)

# %%
auth = OAuthHandler(ckey,csecret)
auth.set_access_token(atoken,asecret)
twitterStream = Stream(auth,listener())
twitterStream.filter(track=["bitcoin"])
# Out:
# #IRM #iRegMed #blockchain #cryptocurrency #healthcare #insurance #tokensale #bitcoin #ethereum https://t.co/9RE5bxghDA
# The latest news from Araw in the official telegram chat: https://t.co/ajUqhXI6HF #cryptocurrency #bitcoin #araw… https://t.co/K8cK3B1ORU
# RT @PlanetZiggurat: AirDrop Calendar https://t.co/KGn0Md6BhX  $AMZN $ETSY $BABA $WMT $TGT $KR $JPM $FB $WFC $GOOG $SNAP $TWTR   $agn $aapl…
# RT @Aruwba: Come see my HOT story before it's deleted!💋
# 😛ONLY $25 FOR LIFE🙀
# Add me now!
# Click Here ➡️ https://t.co/nlE16zz4hC
#
# I no…
# "Satoshi Nakamoto ensured that Bitcoin’s ecosystem was primed for growth with a finite money supply and secure, dec… https://t.co/nd31LTii4m
# RT @Aruwba: Come see my HOT story before it's deleted!💋
# 😛ONLY $25 FOR LIFE🙀
# Add me now!
# Click Here ➡️ https://t.co/nlE16zz4hC
#
# I no…
# The potential of bitcoin tech could elevate agricultural growth
# https://t.co/mMRWC7uyJu
# ...
